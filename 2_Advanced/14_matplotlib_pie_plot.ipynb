# %%
#libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt
import ast

#loading data
dataset=load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()
#cleaning
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])
df['job_skills']=df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df['job_work_from_home'].value_counts().plot(kind='pie',startangle=90,autopct='%1.2f%%',figsize=(6,6))
plt.title('Work From Home Job Postings')
plt.ylabel('')
plt.show()

# %%
fig, ax = plt.subplots(1,3, figsize=(18,6))
dict_column = {'job_work_from_home':'Work From Home',
                'job_no_degree_mention':'Job degree req',
                'job_health_insurance' :'Health Insurance'}
                
for i, (col, title) in enumerate(dict_column.items()):
    ax[i].pie(df[col].value_counts(), labels=df[col].value_counts().index, autopct='%1.2f%%', startangle=90)
    ax[i].set_title(title)
# fig.tight_layout()

# %%
fig, ax = plt.subplots(1,3, figsize=(18,6))
dict_column = {'job_work_from_home':'Work From Home',
                'job_no_degree_mention':'Job degree req',
                'job_health_insurance' :'Health Insurance'}
                
for i, (col, title) in enumerate(dict_column.items()):
  df[col].value_counts().plot(kind='pie',ax=ax[i],startangle=90,autopct='%1.2f%%')
  ax[i].set_title(title)
  ax[i].set_ylabel('')

# %%
columns = ['job_work_from_home', 'job_no_degree_mention', 'job_health_insurance']

fig, ax = plt.subplots(1,3, figsize=(18,6))

for i, col in enumerate(columns):
    df[col].value_counts().plot(kind='pie', ax=ax[i], startangle=90, autopct='%1.2f%%')
    ax[i].set_title(col)   # will show raw name as title
    ax[i].set_ylabel('')

# %%
fig, ax = plt.subplots(1,3, figsize=(18,6))
dict_column = {'job_work_from_home':'Work From Home',
                'job_no_degree_mention':'Job degree req',
                'job_health_insurance' :'Health Insurance'}

for i , (x,y) in enumerate(dict_column.items()):
    ax[i].pie(df[x].value_counts(),
               labels=df[x].value_counts().index,
               autopct='%1.2f%%',
               startangle=90
               )
    ax[i].set_title(y)

# %%
fig, ax = plt.subplots(1,3, figsize=(18,6))
ax[0].pie(df['job_work_from_home'].value_counts(), labels=df['job_work_from_home'].value_counts().index, autopct='%1.2f%%', startangle=90)
ax[1].pie(df['job_no_degree_mention'].value_counts())
ax[2].pie(df['job_health_insurance'].value_counts())
# Out:
# ([<matplotlib.patches.Wedge at 0x27ca67c7e90>,
# ...
#  [Text(-1.0348712468682568, 0.372882692552684, ''),
#   Text(1.0348712794666945, -0.37288260208136126, '')])

# %%
fig, ax = plt.subplots(1,3, figsize=(18,6))
df['job_work_from_home'].value_counts().plot(kind='pie', ax=ax[0], startangle=90, autopct='%1.2f%%')
df['job_no_degree_mention'].value_counts().plot(kind='pie', ax=ax[1], startangle=90, autopct='%1.2f%%')
df['job_health_insurance'].value_counts().plot(kind='bar', ax=ax[2])
# Out:
# <Axes: xlabel='job_health_insurance'>
