# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/your-username/your-repo-name/blob/main/your-notebook.ipynb)

# %% [markdown]
# ## Getting Started w/ Jupyter Notebooks in Colab

# %% [markdown]
# ### Adding and moving cells
# Add new cells by using the + CODE and + TEXT buttons that show when you hover between cells.
#
# You can move a cell by selecting it and clicking Cell Up or Cell Down in the top toolbar.

# %% [markdown]
# ### Markdown Cell vs. Python Cell

# %% [markdown]
# **Markdown Example:**
#
# This is a markdown cell.

# %% [markdown]
# **Python Example:**

# %%
"This is a python cell"
# Out:
# 'This is a python cell'

# %% [markdown]
# ### How to Run a Cell
# **Easy Way:** Click the run button.
#
# **Pro Way:** With cell selected type Ctrl+Enter.

# %% [markdown]
# **Python Basics:**
# Cells print out it's results below the cell.

# %%
2 + 2
# Out:
# 4

# %% [markdown]
# If you have multiple lines only the last line will show.

# %%
2 + 2
3 * 3
# Out:
# 9

# %% [markdown]
# The `print()` function outputs the specified message to the console, allowing you to display text, variables, or the results of expressions.

# %%
print("What's up!")
print(2 + 2)
print(3 * 3) # Technically, I could remove that last print function.and still would print all three
# Out:
# What's up!
# 4
# 9

# %% [markdown]
# **Make a Comment**
# What if you wanted to include something in your code like a note?
#
# - Include a # before the line
# - This is called a comment

# %%
# This is a comment. Nothing to the right of the "#" sign will be interpreted
print("What's Up")
print(2 + 2) # This is a comment also
3 * 3
# Out:
# What's Up
# 4
# 9
